# %% [markdown]
# Comparing my NorESM2.3 run with Dirk's KeyClim run before making simulations of volcanic eruptions.

# %%
import numpy as np
import xarray as xr
import pandas as pd
import cftime
import calendar
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.path as mpath
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib.ticker as mticker
from matplotlib.colors import TwoSlopeNorm
from matplotlib.patches import Rectangle
import imageio
import os
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import datetime #import datetime
from glob import glob

# %%
from check_time import extract_vars
# you need NCO to run this. do conda install -c conda-forge nco

# %%
extract_vars(fld="/projects/NS1004K/elihho/NHISTvsls_tropstratchem_prep_f09_nt14_20220223_test03/atm/hist",
             vars=["TREFHT"],
             ystart=2000,
             yend=2010,
             outfld="/nird/datapeak/NS1004K/mdeb/eli_thesis/test_output",
             ow=True)
# Out:
# Extracting TREFHT from h0 tape for years 2000-2010...
# Script execution time: 70.4943 seconds

# %%
ds = xr.open_dataset("/nird/datapeak/NS1004K/mdeb/eli_thesis/test_output/NHISTvsls_tropstratchem_prep_f09_nt14_20220223_test03/TREFHT_h0_2000-2010.nc")

# %%
ds
# Out:
# <xarray.Dataset> Size: 29MB
# Dimensions:    (time: 132, nbnd: 2, lat: 192, lon: 288)
# Coordinates:
#   * time       (time) object 1kB 2000-02-01 00:00:00 ... 2011-01-01 00:00:00
#   * lat        (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 2kB 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
# Dimensions without coordinates: nbnd
# Data variables:
#     time_bnds  (time, nbnd) object 2kB ...
#     TREFHT     (time, lat, lon) float32 29MB ...
# Attributes:
#     Conventions:       CF-1.0
#     source:            CAM
#     case:              NHISTvsls_tropstratchem_prep_f09_nt14_20220223_test03
#     logname:           olivie
#     host:
#     initial_file:      N1850vsls_tropstratchem_prep_f09_nt14_20220223_test14....
#     topography_file:   /cluster/shared/noresm/inputdata/atm/cam/topo/fv_0.9x1...
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     time_period_freq:  month_1
# ...
